# %% [raw]
# # form of regression,that contain/regularizes or shrink the coefficient estimates towards zero
# Two techniques
# 1 Ridge regularization/L2
# 2 lasso regularization/L1

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
dataset = pd.read_csv(r"C:\Users\Bhakti Gajipara\OneDrive\Documents\machine learing\HousingData.csv")
dataset
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  HousePrice
# 0       15.3  396.90   4.98        24.0
# 1       17.8  396.90   9.14        21.6
# ...

# %%
dataset.isnull().sum()/dataset.shape[0] *100
# Out:
# CRIM          3.952569
# ZN            3.952569
# INDUS         3.952569
# CHAS          3.952569
# NOX           0.000000
# RM            0.000000
# AGE           3.952569
# DIS           0.000000
# RAD           0.000000
# TAX           0.000000
# PTRATIO       0.000000
# B             0.000000
# LSTAT         3.952569
# HousePrice    0.000000
# dtype: float64

# %%
dataset = dataset.fillna(dataset.mean())

# %%
dataset.isnull().sum()/dataset.shape[0] *100
# Out:
# CRIM          0.0
# ZN            0.0
# INDUS         0.0
# CHAS          0.0
# NOX           0.0
# RM            0.0
# AGE           0.0
# DIS           0.0
# RAD           0.0
# TAX           0.0
# PTRATIO       0.0
# B             0.0
# LSTAT         0.0
# HousePrice    0.0
# dtype: float64

# %%
# data_null = dataset[["CRIM","ZN","INDUS","CHAS","AGE","LSTAT"]]

# %%
# data_null = data_null.fillna(data_null.mean())

# %%
# data_null.isnull().sum()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(data = dataset.corr(),annot= True)
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
import numpy as np

# %% [markdown]
# # Linear Regression

# %%
x = dataset.iloc[:,:-1]
y = dataset["HousePrice"]

# %%
sc =StandardScaler()
sc.fit(x)
# Out:
# StandardScaler()

# %%
x = pd.DataFrame(sc.transform(x),columns=x.columns)
x
# Out:
#          CRIM        ZN     INDUS     CHAS        NOX        RM       AGE  \
# 0   -0.472537 -0.476693 -1.852062 -1.39932  -6.037437 -8.364118 -2.503967
# 1   -0.472249 -0.511022 -1.745789 -1.39932 -11.186268 -8.676684 -2.485735
# 2   -0.472250 -0.511022 -1.745789 -1.39932 -11.186268 -7.126030 -2.509423
# 3   -0.472180 -0.511022 -1.854964 -1.39932 -12.007096 -7.505575 -2.529784
# 4   -0.471677 -0.511022 -1.854964 -1.39932 -12.007096 -7.203157 -2.518605
# ..        ...       ...       ...      ...        ...       ...       ...
# 501 -0.471765 -0.511022 -1.637282 -1.39932  -3.425711 -8.327584 -2.498776
# 502 -0.472003 -0.511022 -1.637282 -1.39932  -3.425711 -9.287609 -2.488662
# 503 -0.471790 -0.511022 -1.637282 -1.39932  -3.425711 -7.550227 -2.469632
# 504 -0.471120 -0.511022 -1.637282 -1.39932  -3.425711 -7.919624 -2.471895
# 505 -0.471973 -0.511022 -1.637282 -1.39932  -3.425711 -9.470278 -2.499550
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)* 100
# Out:
# 74.20299863537105

# %%
lr.coef_
# Out:
# array([-8.31918650e+00,  1.52139471e+01, -1.21528596e+00,  2.02519027e-01,
#        -2.14652681e-01,  2.34148946e+00, -1.46677469e+01, -6.73343138e+00,
#         1.68602115e+01, -2.59407954e+02, -4.14467734e+00,  1.02003841e+02,
#        -2.15192333e+01])

# %%
print(mean_squared_error(y_test,lr.predict(x_test)))
print(mean_absolute_error(y_test,lr.predict(x_test)))
print(np.sqrt(mean_squared_error(y_test,lr.predict(x_test))))
# Out:
# 25.01767202384281
# 3.1499233573458345
# 5.001766890194185

# %%
plt.figure(figsize=(10,5))
plt.bar(x.columns,lr.coef_)
plt.title("Linear Regression")
plt.xlabel("columns")
plt.ylabel("cof")
# Out:
# Text(0, 0.5, 'cof')

# %% [markdown]
# # Lasso

# %%
la =Lasso(alpha=0.01)
la.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.01)

# %%
la.score(x_train,y_train)
# Out:
# 0.7249456506923686

# %%
print(mean_squared_error(y_test,la.predict(x_test)))
print(mean_absolute_error(y_test,la.predict(x_test)))
print(np.sqrt(mean_squared_error(y_test,la.predict(x_test))))
# Out:
# 25.451443711627743
# 3.22977726400515
# 5.044942389326933

# %%
plt.figure(figsize=(10,5))
plt.bar(x.columns,la.coef_)
plt.title("Lasso")
plt.xlabel("columns")
plt.ylabel("cof")
# Out:
# Text(0, 0.5, 'cof')

# %% [markdown]
# # Ridge

# %%
ri = Ridge(alpha=0.01)
ri.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.01)

# %%
ri.score(x_train,y_train)
# Out:
# 0.7392633423626296

# %%
print(mean_squared_error(y_test,ri.predict(x_test)))
print(mean_absolute_error(y_test,ri.predict(x_test)))
print(np.sqrt(mean_squared_error(y_test,ri.predict(x_test))))
# Out:
# 25.232102959513366
# 3.1868895357090103
# 5.023156672801812

# %%
plt.figure(figsize=(10,5))
plt.bar(x.columns,ri.coef_)
plt.title("Ridge")
plt.xlabel("columns")
plt.ylabel("cof")
# Out:
# Text(0, 0.5, 'cof')

# %%
df = pd.DataFrame({"column_name":x.columns,"Linear Regression":lr.coef_,"Lasso":la.coef_,"Ridge":ri.coef_})
df
# Out:
#    column_name  Linear Regression      Lasso      Ridge
# 0         CRIM          -8.319187  -7.200276  -8.389297
# 1           ZN          15.213947   0.000000  10.586099
# 2        INDUS          -1.215286  -3.011918  -3.474821
# 3         CHAS           0.202519   0.236685   0.218134
# 4          NOX          -0.214653  -0.255474  -0.230501
# 5           RM           2.341489   2.351640   2.354091
# 6          AGE         -14.667747  -0.000000 -13.646099
# 7          DIS          -6.733431  -5.377051  -6.642138
# 8          RAD          16.860212   2.326308   7.797192
# 9          TAX        -259.407954  -0.000000 -35.240726
# 10     PTRATIO          -4.144677  -4.357805  -4.234492
# 11           B         102.003841   0.000000  81.144828
# 12       LSTAT         -21.519233 -23.055568 -21.871957
