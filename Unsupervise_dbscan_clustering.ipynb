# %% [markdown]
# # DBSCAN Clustering

# %% [raw]
# # it is applicable for non-linear dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_moons

# %%
x,y = make_moons(n_samples=250,noise=0.05)

# %%
df = {"data1":x[:,0],"data2":x[:,1]}

# %%
dataset = pd.DataFrame(df)

# %%
dataset
# Out:
#         data1     data2
# 0   -0.882020  0.452239
# 1    0.933868 -0.513402
# 2    1.813440 -0.042244
# 3   -0.939688  0.514666
# 4   -0.039633  1.000439
# ..        ...       ...
# 245  0.692044 -0.524141
# 246  0.389192 -0.182171
# 247  0.245969 -0.082129
# 248 -0.937970  0.096242
# 249  0.460612 -0.485823
#
# [250 rows x 2 columns]

# %%
sns.scatterplot(x = "data1",y = "data2",data = dataset)
# Out:
# <Axes: xlabel='data1', ylabel='data2'>

# %%
from sklearn.cluster import DBSCAN

# %%
db = DBSCAN(eps= 0.2,min_samples=5)

# %%
dataset["predict"] = db.fit_predict(dataset)

# %%
 sns.scatterplot(x = "data1",y = "data2",data = dataset,hue = "predict")
# Out:
# <Axes: xlabel='data1', ylabel='data2'>
