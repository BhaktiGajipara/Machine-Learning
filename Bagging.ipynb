# %% [raw]
# # In bagging Original dataset divides into many subset(bag) anf each data train on same model and average result od all dataset is a final result
# it increase accuracy of model

# %% [raw]
# # Bagging Algorithms
# 1 Bagging meta-estimator
# 2 Random Forest

# %% [markdown]
# ## Bagging estimator and Random Forest in classification

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_moons

# %%
x,y = make_moons(n_samples=1000,noise=0.2)

# %%
df = {"x1":x[:,0],"x2":x[:,1],"y":y}

# %%
dataset = pd.DataFrame(df)

# %%
sns.scatterplot(x = "x1",y = "x2",data = dataset,hue="y")
# Out:
# <Axes: xlabel='x1', ylabel='x2'>

# %%
x = dataset.iloc[:,:-1]
y = dataset["y"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
bg = BaggingClassifier(estimator=SVC(),n_estimators=50)
bg.fit(x_train,y_train)
# Out:
# BaggingClassifier(estimator=SVC(), n_estimators=50)

# %%
bg.score(x_train,y_train),bg.score(x_test,y_test)
# Out:
# (0.9625, 0.985)

# %%
rf = RandomForestClassifier(n_estimators=30)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=30)

# %%
rf.score(x_train,y_train),rf.score(x_test,y_test)
# Out:
# (1.0, 0.975)

# %% [markdown]
# ## Bagging estimator and Random Forest in Regression

# %%
dataset1 = pd.read_csv(r"C:\Users\Bhakti Gajipara\OneDrive\Documents\machine learing\placement.csv")
dataset1
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
x1 = dataset1.iloc[:,:-1]
y1 = dataset1["package"]

# %%
x1_train,x1_test,y1_train,y1_test = train_test_split(x1,y1,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

# %%
bg1 = BaggingRegressor(estimator=LinearRegression(),n_estimators=40)
bg1.fit(x1_train,y1_train)
bg1.score(x1_train,y1_train),bg1.score(x1_test,y1_test)
# Out:
# (0.7757687024891206, 0.7742546308466995)

# %%
rf1 = RandomForestRegressor(n_estimators=10)
rf1.fit(x1_train,y1_train)
rf1.score(x1_train,y1_train) , rf1.score(x1_test,y1_test)
# Out:
# (0.9146942760201358, 0.6472457227246009)
