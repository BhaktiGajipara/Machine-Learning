# %%
import pandas as pd
import matplotlib.pyplot as mlt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

# %% [raw]
# describe the probability of an event based on prior knowledge of conditions that might be related to event
# Naive: called naive because it assumes that occurance of certain features is independent of occurance of other features

# %% [raw]
# # Types of Bayes Model
# 1 Gaussian Naive Bayes : suitable when data is in normal distribution
# 2 Bernoulli Naive Bayes : suitable when data is in boolean or binary features
# 3 Multinomial Naive Bayes : used for discrete data,such as text data

# %%
dataset = pd.read_csv(r"C:\Users\Bhakti Gajipara\Downloads\Social_Network_Ads.csv")
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset.drop(columns=["User ID","Gender"],inplace = True)

# %%
dataset.isnull().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
sns.kdeplot(data = dataset["Age"])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.scatterplot(x = "Age",y = "EstimatedSalary",data = dataset,hue = "Purchased")
# Out:
# <Axes: xlabel='Age', ylabel='EstimatedSalary'>

# %%
x = dataset.iloc[:,:-1]
y = dataset["Purchased"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB

# %%
gnb = GaussianNB()
gnb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
gnb.score(x_test,y_test),gnb.score(x_train,y_train)
# Out:
# (0.925, 0.8625)

# %%
mnb = MultinomialNB()
mnb.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
mnb.score(x_test,y_test),mnb.score(x_train,y_train)
# Out:
# (0.6, 0.653125)

# %%
bnb = BernoulliNB()
bnb.fit(x_train,y_train)
# Out:
# BernoulliNB()

# %%
bnb.score(x_test,y_test),bnb.score(x_train,y_train)
# Out:
# (0.65, 0.640625)

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf = gnb)
# Out:
# C:\Users\Bhakti Gajipara\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf = mnb)
# Out:
# C:\Users\Bhakti Gajipara\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MultinomialNB was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf = bnb)
# Out:
# C:\Users\Bhakti Gajipara\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but BernoulliNB was fitted with feature names
#   warnings.warn(
# <Axes: >
