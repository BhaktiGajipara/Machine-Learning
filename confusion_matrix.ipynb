# %% [raw]
# confusion matrix is maxtrix contain y_test(actual input) and predicted input
# it compare both and gave accuracy
#
# here Negative mean 0
# and Positive mean 1
#
# TrueNegative(1-1)
# FalsePositive(0-1)
# FalseNegative(1-0)
# TrueNegative(0-0)
#
#
# Precision : TP/(TP+FP)
# Recall : TP/(TP+FN)    //Recall value should be high
# F1 : it is harmonic mean of precision and recall.it take both false positive and false negative into account
#     F1 score = 2 * (precision * recall)/ (precision + recall)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"C:\Users\Bhakti Gajipara\Downloads\Social_Network_Ads.csv")
dataset.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
dataset.drop(columns=["User ID","Gender"],inplace=True)

# %%
dataset
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
x = dataset.iloc[:,:-1]
y = dataset["Purchased"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.9

# %%
from sklearn.metrics import confusion_matrix,precision_score,recall_score,f1_score

# %%
cf = confusion_matrix(y_test,lr.predict(x_test))
cf
# Out:
# array([[48,  4],
#        [ 4, 24]], dtype=int64)

# %%
sns.heatmap(cf,annot= True)
# Out:
# <Axes: >

# %%
 precision_score(y_test,lr.predict(x_test))
# Out:
# 0.8571428571428571

# %%
recall_score(y_test,lr.predict(x_test))
# Out:
# 0.8571428571428571

# %%
f1_score(y_test,lr.predict(x_test))
# Out:
# 0.8571428571428571
