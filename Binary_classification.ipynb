# %% [markdown]
# # classification

# %% [raw]
# this algorithm used to identify the category of new observation on the basis of training data
# # Two types
# 1 Binary classification (only two possible outcomes)
# 2 multi-class classification (have more than two outcomes)

# %% [raw]
# # Types of Ml classification types
# 1 Linear Model
#     1 logistic
#     2 support vector
# 2 Non-linear model
#     1 k-nearest vector
#     2 desicion tree classification
#     3 random forest classification
#     4 SVM
#     5 Naive Bayes

# %% [raw]
# # Evaluating classification Model
# 1 Log loss or cross entropy
# 2 confution Matrix
# 3 AUC ROC curve

# %% [markdown]
# # Logistic Regression And Binary classification

# %% [raw]
# # data should be linearly separatable
# Three Types
# 1 Binomial  (2 possible types of dependent variables)
# 2 multinominal  (3 or more unordered types of dependent variables)
# 3 Ordinal  (3 or more ordered types of dependent variables)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r"C:\Users\Bhakti Gajipara\Downloads\Social_Network_Ads.csv")
dataset.drop(columns=["User ID","Gender","EstimatedSalary"],inplace= True)

# %%
dataset
# Out:
#      Age  Purchased
# 0     19          0
# 1     35          0
# 2     26          0
# 3     27          0
# 4     19          0
# ..   ...        ...
# 395   46          1
# 396   51          1
# 397   50          1
# 398   36          0
# 399   49          1
#
# [400 rows x 2 columns]

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x="Age",y = "Purchased",data = dataset)
# Out:
# <Axes: xlabel='Age', ylabel='Purchased'>

# %%
x = dataset.iloc[:,:-1]
y = dataset["Purchased"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.20,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.9125

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x="Age",y = "Purchased",data = dataset)
sns.lineplot(x = "Age",y = lr.predict(x),data = dataset)
# Out:
# <Axes: xlabel='Age', ylabel='Purchased'>

# %% [markdown]
# # Logistic Regression And Binary classification, Multiple Input

# %%
df = pd.read_csv(r"C:\Users\Bhakti Gajipara\Downloads\Social_Network_Ads.csv")
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df.drop(columns=["User ID","Gender"],inplace= True)

# %%
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
sns.scatterplot(x = "Age",y = "EstimatedSalary",data = df,hue="Purchased")
# Out:
# <Axes: xlabel='Age', ylabel='EstimatedSalary'>

# %%
x1 = df.iloc[:,:-1]
y1= df["Purchased"]

# %%
from sklearn.model_selection import train_test_split

# %%
x1_train,x1_test,y1_train,y1_test = train_test_split(x1,y1,test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x1_train,y1_train)
# Out:
# LogisticRegression()

# %%
lr.score(x1_test,y1_test)*100
# Out:
# 90.0

# %%
sns.scatterplot(x = "Age",y = "EstimatedSalary",data = df,hue="Purchased")
sns.lineplot(x = "Age",y = "EstimatedSalary",data = df,hue=lr.predict(x1))
# Out:
# <Axes: xlabel='Age', ylabel='EstimatedSalary'>

# %%
lr.predict([[22,22000]])
# Out:
# C:\Users\Bhakti Gajipara\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
lr.coef_
# Out:
# array([[2.23440597e-01, 3.33895692e-05]])

# %%
lr.intercept_
# Out:
# array([-11.79557135])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plt.figure(figsize=(5,5))
plot_decision_regions(x1.to_numpy(),y1.to_numpy(),clf = lr)
plt.show()
# Out:
# C:\Users\Bhakti Gajipara\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Logistic Regression And Binary classification, polynomial Input

# %%
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
sns.scatterplot(x = "Age",y = "EstimatedSalary",data = df,hue="Purchased")
# Out:
# <Axes: xlabel='Age', ylabel='EstimatedSalary'>

# %%
x2 = df.iloc[:,:-1]
y2= df["Purchased"]

# %%
 from sklearn.preprocessing import PolynomialFeatures

# %%
pf = PolynomialFeatures(degree=4)
pf.fit(x2)
x2 = pd.DataFrame(pf.transform(x2))

# %%
x2_train,x2_test,y2_train,y2_test = train_test_split(x2,y2,test_size=0.2,random_state=25)

# %%
lr1 = LogisticRegression()
lr1.fit(x2_train,y2_train)
# Out:
# LogisticRegression()

# %%
lr1.score(x2_test,y2_test)*100
# Out:
# 80.0
