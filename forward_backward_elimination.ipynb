# %%
import pandas as pd
from mlxtend.feature_selection import SequentialFeatureSelector
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer, accuracy_score

# %%
 dataset = pd.read_csv(r"C:\Users\Bhakti Gajipara\OneDrive\Documents\machine learing\diabetes.csv")
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
x = dataset.iloc[:,:-1]
y = dataset["Outcome"]

# %%
x.shape
# Out:
# (768, 8)

# %%
lr = LogisticRegression()

# %%
fs = SequentialFeatureSelector(lr,n_features_to_select= 2,direction = "forward")
# fs = SequentialFeatureSelector(lr, k_features=(1,8))

fs.fit(x,y)
# Out:
# SequentialFeatureSelector(estimator=LogisticRegression(),
#                           n_features_to_select=2)

# %%
fs.feature_names_in_
# Out:
# array(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness',
#        'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age'], dtype=object)

# %%
fs.n_features_in_
# Out:
# 8
