# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [raw]
# # types of regression
# 1. Linear
# 2 multi-linear
# 3 Lasoo
# 4 Ridge
# 5 polynomial
# 6 Decision Tree
# 7 Random Forest
# 8 supportibve vector
# 9 k-nearest neigboure

# %% [raw]
# # Linear regression Algorithm
# use when only one input data
# Equation y = mx+c

# %% [markdown]
# # Linear Regression

# %%
dataset = pd.read_csv(r"C:\Users\Bhakti Gajipara\OneDrive\Documents\machine learing\placement.csv")
dataset.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x = "cgpa", y = "package", data = dataset)
plt.show()

# %%
dataset.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
x = dataset[["cgpa"]]
y = dataset["package"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25,random_state=54)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict([[6.89]])
# Out:
# C:\Users\Bhakti Gajipara\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.9383878])

# %%
lr.score(x_train,y_train)
# Out:
# 0.7974504935595004

# %%
y_prd = lr.predict(x)

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x = "cgpa", y = "package", data = dataset)
plt.plot(dataset["cgpa"],y_prd,c="red")
plt.show()

# %% [markdown]
# # multilinear regression

# %%
df = pd.read_csv(r"C:\Users\Bhakti Gajipara\OneDrive\Documents\machine learing\Salary_data.csv")
df.head()
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731
# 3              2.0  22.0   43525
# 4              2.2  22.2   39891

# %%
df.shape
# Out:
# (30, 3)

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Age                0
# Salary             0
# dtype: int64

# %%
sns.pairplot(data = df)

# %%
sns.heatmap(data = dataset.corr(),annot = True)
# Out:
# <Axes: >

# %%
x1 = df.iloc[:,:-1]
y1 = df["Salary"]

# %%
x1_train, x1_test, y1_train, y1_test = train_test_split(x1,y1,test_size=0.2,random_state=42)

# %%
lr1 = LinearRegression()
lr1.fit(x1_train,y1_train)
# Out:
# LinearRegression()

# %%
lr1.score(x1_train,y1_train)
# Out:
# 0.9700017923404649

# %%
lr1.predict(x1_test)
# Out:
# array([118686.60525402,  67497.80208802, 101581.52273219,  74585.69879684,
#         54833.367916  ,  58044.6977654 ])

# %%
x1_test
# Out:
#     YearsExperience   Age
# 27              9.6  36.0
# 15              4.9  25.0
# 23              8.2  32.0
# 17              5.3  27.0
# 8               3.2  23.3
# 9               3.7  23.6
